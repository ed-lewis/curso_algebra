# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Vetor que receberá a transformação
vetorT = np.array([[3,2],[2,5]])
vetorT
# Out:
# array([[3, 2],
#        [2, 5]])

# %%
# Matriz de transformação linear (translação)
T = np.array([[4,1],[4,1]])
T
# Out:
# array([[4, 1],
#        [4, 1]])

# %%
# Coordenadas do vetoTr
x = [vetorT[0][0], vetorT[1][0]]
y = [vetorT[0][1], vetorT[1][1]]

# %%
plt.plot(x,y, color = 'blue');

# %%
matrizT = vetorT + T
matrizT
# Out:
# array([[7, 3],
#        [6, 6]])

# %%
xT = [matrizT[0][0], matrizT[1][0]]
yT = [matrizT[0][1], matrizT[1][1]]
plt.plot(x,y, color = 'blue');
plt.plot(xT,yT, color = 'red');
plt.show()
