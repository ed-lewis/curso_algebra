# %%
import sys
import numpy as np

# %%
print(f"Versão do Python: {sys.version}")
print(f"Versão do NumPy: {np.__version__}")
# Out:
# Versão do Python: 3.12.12 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 20:05:38) [MSC v.1929 64 bit (AMD64)]
# Versão do NumPy: 2.4.1
